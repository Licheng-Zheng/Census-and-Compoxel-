# %%
# 1. Install FLAME GPU
# %pip install --extra-index-url https://whl.flamegpu.com/whl/cuda120/ pyflamegpu

# The project is public because I don't want to use an SSH key yet, so I made it public for simplicity 
# !git clone https://github.com/Licheng-Zheng/Census-and-Compoxel-.git
# %cd Census-and-Compoxel-/Compoxel
# Out:
# Looking in indexes: https://pypi.org/simple, https://whl.flamegpu.com/whl/cuda120/
# Collecting pyflamegpu
#   Downloading https://github.com/FLAMEGPU/FLAMEGPU2/releases/download/v2.0.0-rc.4/pyflamegpu-2.0.0rc4%2Bcuda120-cp312-cp312-linux_x86_64.whl (177.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.0/177.0 MB 6.7 MB/s eta 0:00:0000:0100:01
# Installing collected packages: pyflamegpu
# Successfully installed pyflamegpu-2.0.0rc4+cuda120
# Cloning into 'Census-and-Compoxel-'...
# remote: Enumerating objects: 57, done.
# remote: Counting objects: 100% (57/57), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 57 (delta 13), reused 49 (delta 10), pack-reused 0 (from 0)
# Receiving objects: 100% (57/57), 17.60 MiB | 17.47 MiB/s, done.
# Resolving deltas: 100% (13/13), done.
# /content/Census-and-Compoxel-/Compoxel

# %%
import os

def print_files_in_current_folder():
    folder_path = os.getcwd()
    print("current folder ", folder_path)
    print("Here are all items in this folder")
    for entry in os.listdir(folder_path):
        full_path = os.path.join(folder_path, entry)
        if os.path.isfile(full_path):
            print(f"File: {entry}")
        elif os.path.isdir(full_path):
            print(f"Folder: {entry}")
print_files_in_current_folder()
# Out:
# current folder  /content/Census-and-Compoxel-/Compoxel
# Here are all items in this folder
# File: main.ipynb
# File: test.py
# File: main.py
# Folder: src
# Folder: kernels

# %%
# !python main.py
# Out:
# Timmy says hello to you! 1
# Traceback (most recent call last):
#   File "/content/Census-and-Compoxel-/Compoxel/main.py", line 8, in <module>
#     model = create_model()
#             ^^^^^^^^^^^^^^
#   File "/content/Census-and-Compoxel-/Compoxel/src/model.py", line 27, in create_model
#     force_func.setMessageInput("location_message")
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pyflamegpu/pyflamegpu.py", line 8101, in setMessageInput
#     return _pyflamegpu.AgentFunctionDescription_setMessageInput(self, *args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# pyflamegpu.pyflamegpu.FLAMEGPURuntimeException: (InvalidMessageType) /__w/FLAMEGPU2/FLAMEGPU2/src/flamegpu/model/AgentFunctionDescription.cpp(219): Message ('location_message') type 'MessageSpatial3D' does not match type 'in' applied to FLAMEGPU_AGENT_FUNCTION ('force_kernel'), in AgentFunctionDescription::setMessageInput().
