# %%
# 1. Install FLAME GPU
# %pip install --extra-index-url https://whl.flamegpu.com/whl/cuda120/ pyflamegpu

# The project is public because I don't want to use an SSH key yet, so I made it public for simplicity 
# !git clone https://github.com/Licheng-Zheng/Census-and-Compoxel-.git
# %cd Census-and-Compoxel-/Compoxel
# Out:
# Looking in indexes: https://pypi.org/simple, https://whl.flamegpu.com/whl/cuda120/
# Requirement already satisfied: pyflamegpu in /usr/local/lib/python3.12/dist-packages (2.0.0rc4+cuda120)
# Cloning into 'Census-and-Compoxel-'...
# remote: Enumerating objects: 52, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 52 (delta 10), reused 44 (delta 7), pack-reused 0 (from 0)
# Receiving objects: 100% (52/52), 17.60 MiB | 29.79 MiB/s, done.
# Resolving deltas: 100% (10/10), done.
# /content/Census-and-Compoxel-/Census-and-Compoxel-/Compoxel

# %%
import os

def print_files_in_current_folder():
    folder_path = os.getcwd()
    print("current folder ", folder_path)
    print("Here are all items in this folder")
    for entry in os.listdir(folder_path):
        full_path = os.path.join(folder_path, entry)
        if os.path.isfile(full_path):
            print(f"File: {entry}")
        elif os.path.isdir(full_path):
            print(f"Folder: {entry}")
print_files_in_current_folder()
# Out:
# current folder  /content/Census-and-Compoxel-/Census-and-Compoxel-/Compoxel
# Here are all items in this folder
# File: main.ipynb
# File: test.py
# File: main.py
# Folder: src
# Folder: kernels

# %%
# !python main.py
# Out:
# Traceback (most recent call last):
#   File "/content/Census-and-Compoxel-/Census-and-Compoxel-/Compoxel/main.py", line 2, in <module>
#     from Compoxel.src.model import create_model
# ModuleNotFoundError: No module named 'Compoxel'
