# %%
# 1. Install FLAME GPU
# %pip install --extra-index-url https://whl.flamegpu.com/whl/cuda120/ pyflamegpu

# The project is public because I don't want to use an SSH key yet, so I made it public for simplicity 
# !git clone https://github.com/Licheng-Zheng/Census-and-Compoxel-.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://whl.flamegpu.com/whl/cuda120/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.0/177.0 MB 4.9 MB/s eta 0:00:0000:0100:01
# ...
# Cloning into 'Census-and-Compoxel-'...
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 34 (delta 2), reused 29 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (34/34), 17.60 MiB | 15.83 MiB/s, done.
# Resolving deltas: 100% (2/2), done.
# [Errno 2] No such file or directory: 'molecular-dynamics-flamegpu'
# /content
# python3: can't open file '/content/main.py': [Errno 2] No such file or directory

# %%
import os

def get_current_directory():
    return os.getcwd()
print(get_current_directory())

# 3. Enter the folder
# %cd Compoxel

# 4. Run the simulation
# !python main.py
# Out:
# /content
# [Errno 2] No such file or directory: 'Compoxel'
# /content
# python3: can't open file '/content/main.py': [Errno 2] No such file or directory

# %%
import os

# ---------------------------------------------------------
# CONFIGURATION
# ---------------------------------------------------------
# 1. Your GitHub Username
USER = "Licheng-Zheng"  # <--- CHANGE THIS!

# 2. The name of the repository you pushed to GitHub
# Based on your logs, it is likely this:
REPO_NAME = "Census-and-Compoxel-" 

# 3. The sub-folder where your code actually lives
PROJECT_FOLDER = "Compoxel"
# ---------------------------------------------------------

# A. Clone the Repository (The Parent)
if not os.path.exists(REPO_NAME):
    print(f"Downloading {REPO_NAME}...")
    # We use f-strings to insert your variables automatically
    # !git clone https://github.com/{USER}/{REPO_NAME}.git
else:
    print("Repository already exists. Pulling changes...")
    # %cd {REPO_NAME}
    # !git pull
    # %cd ..

# B. Navigate into the specific sub-folder
# We need to go: /content -> Census-and-Compoxel- -> Compoxel
TARGET_PATH = os.path.join(REPO_NAME, PROJECT_FOLDER)

try:
    # Change directory to the subfolder
    os.chdir(TARGET_PATH)
    print(f"Success! Current working directory: {os.getcwd()}")
    
    # Verify main.py is actually here
    if "main.py" in os.listdir():
        print("Found main.py! Ready to run.")
    else:
        print("WARNING: main.py not found here. Files present:", os.listdir())
        
except FileNotFoundError:
    print(f"ERROR: Could not find folder '{TARGET_PATH}'.")
    print("Folders found in root:", os.listdir(REPO_NAME))

# C. Run the simulation
# Only run if we found the file
if os.path.exists("main.py"):
    # !python main.py
# Out:
# Current directory: /content
# ...
# Cloning into 'Compoxel'...
# fatal: could not read Username for 'https://github.com': No such device or address
# [Errno 2] No such file or directory: 'Compoxel'
# /content
# Success! Now inside: /content
# python3: can't open file '/content/main.py': [Errno 2] No such file or directory
