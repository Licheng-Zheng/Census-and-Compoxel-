# %%
# 1. Install FLAME GPU
# !pip install --extra-index-url https://whl.flamegpu.com/whl/cuda120/ pyflamegpu

# 2. Download your code
# Note: If your repo is Private, you will need to set up an SSH key or token.
# For now, if it's Public, this works instantly:
# !git clone https://github.com/YourUsername/molecular-dynamics-flamegpu.git

# 3. Enter the folder
# %cd molecular-dynamics-flamegpu

# 4. Run the simulation
# !python main.py
