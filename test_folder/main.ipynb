# %%
# 1. Mount Google Drive (Optional, but highly recommended for saving JSONs)
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# 2. Clean up any previous runs and clone fresh
# !rm -rf /content/Census-and-Compoxel-
# !git clone --branch rejection_sampling --single-branch https://github.com/Licheng-Zheng/Census-and-Compoxel-.git   

# 3. Navigate to the root folder (Assuming CMakeLists.txt is at the root of the repo)
# If CMakeLists.txt is inside a subfolder, append it here (e.g., /Compoxel)
# %cd /content/Census-and-Compoxel-/Compoxel

# Verify we are in the right place and can see CMakeLists.txt
# !ls
# Out:
# Mounted at /content/drive
# Cloning into 'Census-and-Compoxel-'...
# remote: Enumerating objects: 125, done.
# remote: Counting objects: 100% (125/125), done.
# remote: Compressing objects: 100% (88/88), done.
# remote: Total 125 (delta 40), reused 106 (delta 26), pack-reused 0 (from 0)
# Receiving objects: 100% (125/125), 17.62 MiB | 17.86 MiB/s, done.
# Resolving deltas: 100% (40/40), done.
# /content/Census-and-Compoxel-/Compoxel
# Cmakelists.txt	config.json  kernels  main.ipynb  Part-Outline	src

# %%
# build directory
# !mkdir -p build
# %cd build

# Configure the project with CMake
# !cmake ..

# Compile the executable using 2 CPU cores to speed it up
# !make -j2
# Out:
# /content/Census-and-Compoxel-/Compoxel/build
# CMake Warning:
#   Ignoring extra path from command line:
#
#    ".."
#
#
# CMake Error: The source directory "/content/Census-and-Compoxel-/Compoxel" does not appear to contain CMakeLists.txt.
# Specify --help for usage, or press the help button on the CMake GUI.
# make: *** No targets specified and no makefile found.  Stop.

# %%
# Ensure we are still in the build directory
# %cd /content/Census-and-Compoxel-/build

# Run the C++ simulation engine
# !./CompoxelVis
# Out:
# [Errno 2] No such file or directory: '/content/Census-and-Compoxel-/build'
# /content/Census-and-Compoxel-/Compoxel/build
# /bin/bash: line 1: ./CompoxelVis: No such file or directory

# %%
import os

output_file = "/content/Census-and-Compoxel-/build/output.json"

if os.path.exists(output_file):
    print("✅ Simulation complete! Output JSON generated successfully.")
    # Optional: Copy it to your Google Drive so you don't lose it when Colab closes
    # !cp {output_file} /content/drive/MyDrive/
else:
    print("❌ Error: output.json was not found. Check the C++ execution logs above.")
# Out:
# ❌ Error: output.json was not found. Check the C++ execution logs above.
